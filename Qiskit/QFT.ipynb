# %%
from qiskit import QuantumCircuit, QuantumRegister
import numpy as np
from QFT import qft
# Out:
# Hello world!

# %%
qc = QuantumCircuit(3)
qr = QuantumRegister(3)

# %%
qft(qc=qc, qr=qr)

# %%
print(qc)
# Out:
#      ┌───┐                                         ░
# q_0: ┤ H ├─■─────────■─────────────────────────────░─
#      └───┘ │U1(π/2)  │        ┌───┐                ░
# q_1: ──────■─────────┼────────┤ H ├─■──────────────░─
#                      │U1(π/4) └───┘ │U1(π/2) ┌───┐ ░
# q_2: ────────────────■──────────────■────────┤ H ├─░─
#                                              └───┘ ░

# %%
qc.draw(output='mpl')

# %%
from qiskit import Aer, execute
from qiskit.visualization import plot_histogram

# %%
Aer.backends()
# Out:
# [AerSimulator('aer_simulator'),
#  AerSimulator('aer_simulator_statevector'),
#  AerSimulator('aer_simulator_density_matrix'),
#  AerSimulator('aer_simulator_stabilizer'),
#  AerSimulator('aer_simulator_matrix_product_state'),
#  AerSimulator('aer_simulator_extended_stabilizer'),
#  AerSimulator('aer_simulator_unitary'),
#  AerSimulator('aer_simulator_superop'),
#  QasmSimulator('qasm_simulator'),
#  StatevectorSimulator('statevector_simulator'),
#  UnitarySimulator('unitary_simulator'),
#  PulseSimulator('pulse_simulator')]

# %%
sim = Aer.get_backend('statevector_simulator')
result = execute(qc, backend=sim, shots=3000).result()

# %%
print(result.get_statevector())
# Out:
# Statevector([0.35355339+0.j, 0.35355339+0.j, 0.35355339+0.j,
#              0.35355339+0.j, 0.35355339+0.j, 0.35355339+0.j,
#              0.35355339+0.j, 0.35355339+0.j],
#             dims=(2, 2, 2))

# %%
plot_histogram(result.get_counts(), title="3-Qubit Circuit", color="orange")

# %% [markdown]
# Another quantum circuit

# %%
qc1 = QuantumCircuit(5)
qr1 = QuantumRegister(5)

# %%
qft(qc1, qr1)

# %%
qc1.draw(output='mpl')

# %%
print(qc1)
# Out:
#      ┌───┐                                                                  »
# q_0: ┤ H ├─■─────────■──────────────■───────────────────■───────────────────»
#      └───┘ │U1(π/2)  │        ┌───┐ │                   │                   »
# q_1: ──────■─────────┼────────┤ H ├─┼─────────■─────────┼──────────■────────»
#                      │U1(π/4) └───┘ │         │U1(π/2)  │          │        »
# q_2: ────────────────■──────────────┼─────────■─────────┼──────────┼────────»
#                                     │U1(π/8)            │          │U1(π/4) »
# q_3: ───────────────────────────────■───────────────────┼──────────■────────»
#                                                         │U1(π/16)           »
# q_4: ───────────────────────────────────────────────────■───────────────────»
#                                                                             »
# «                                                             ░
# ...

# %%
sim = Aer.get_backend('statevector_simulator')
result1 = execute(qc1, backend=sim, shots=3000).result()

# %%
result1.backend_name
# Out:
# 'statevector_simulator'

# %%
result1.get_statevector()
# Out:
# Statevector([0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j,
#              0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j,
#              0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j,
#              0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j,
#              0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j,
#              0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j,
#              0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j,
#              0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j, 0.1767767+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
plot_histogram(result1.get_counts(), color="crimson", title="5-Qubit Circuit", figsize=(20,20))

# %%
# ?qc.cu
# Out:
# Signature:
# qc.cu(
#     theta: Union[qiskit.circuit.parameterexpression.ParameterExpression, float],
#     phi: Union[qiskit.circuit.parameterexpression.ParameterExpression, float],
#     lam: Union[qiskit.circuit.parameterexpression.ParameterExpression, float],
#     gamma: Union[qiskit.circuit.parameterexpression.ParameterExpression, float],
#     control_qubit: Union[qiskit.circuit.quantumregister.Qubit, qiskit.circuit.quantumregister.QuantumRegister, int, slice, Sequence[Union[qiskit.circuit.quantumregister.Qubit, int]]],
#     target_qubit: Union[qiskit.circuit.quantumregister.Qubit, qiskit.circuit.quantumregister.QuantumRegister, int, slice, Sequence[Union[qiskit.circuit.quantumregister.Qubit, int]]],
#     label: Optional[str] = None,
#     ctrl_state: Union[int, str, NoneType] = None,
# ) -> qiskit.circuit.instructionset.InstructionSet
# Docstring:
# Apply :class:`~qiskit.circuit.library.CUGate`.
#
# ...
